# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
path = 'price_stock.csv'
dataframe = pd.read_csv(path)

# %%
df_transposed = dataframe.T
df_transposed
# Out:
#              0           1           2           3           4           5    \
# Ngày  21-12-2021  20-12-2021  17-12-2021  16-12-2021  15-12-2021  14-12-2021
# ABS         28.7        27.5       27.75       27.65        27.0        26.6
# ABT         37.5        37.5        37.3        37.5        37.5        37.0
# ACB         32.8        33.1        33.2        33.0        33.4        33.3
# ACC         26.2       26.25        26.0       25.85        25.9        25.8
# ...          ...         ...         ...         ...         ...         ...
# HHS        12.95        12.5       12.65       12.75       11.95        11.8
# HNG         11.1        10.7        10.4       11.15        10.6        11.2
# HPG         46.1        46.9        46.7        47.5        47.8        47.7
# HQC          8.6        8.26         8.0         8.6        8.05         7.7
# HSG        34.85        35.7        36.1       37.15        37.5        37.6
#
# ...

# %%
from tslearn.preprocessing import TimeSeriesScalerMeanVariance

# %%
X = TimeSeriesScalerMeanVariance().fit_transform(df_transposed.iloc[1:])
X.shape
# Out:
# (60, 242, 1)

# %%
X = X.reshape(60,242)

# %%
from sklearn.cluster import KMeans
from sklearn import metrics
from scipy.spatial.distance import cdist
from tslearn.clustering import TimeSeriesKMeans

# %%
sz = X.shape[0]

# %%
distortions = []
K = range(1, 30)
 
for k in K:
    km_sdtw = TimeSeriesKMeans(n_clusters=k, metric="softdtw", max_iter=5,max_iter_barycenter=5,metric_params={"gamma": .5},random_state=0).fit(X)
    distortions.append(km_sdtw.inertia_)

# %%
plt.figure(figsize=(20,10))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()
